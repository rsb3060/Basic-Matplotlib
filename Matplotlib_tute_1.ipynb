# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x=[1,2,3]
y=[5,7,4]
plt.plot(x,y,label="First Line")

# %%
x=[1,2,3]
y=[5,7,4]
plt.plot(x,y,label="First Line")
x2=[1,2,3]
y2=[10,14,12]
plt.plot(x2,y2,label="Second Line")
plt.xlabel("Plot Number")
plt.ylabel("Important Var")

plt.title("Satarting matplotlib\nCheck it out")
plt.legend()
#plt.show()

# %%
fig=plt.figure()
x=[2,4,6,8,10]
y=[5,6,7,8,4]
x2=[3,5,9,12,7]
y2=[2,5,1,9,6]
plt.bar(x,y,label="Bars 1",color="b")
plt.bar(x2,y2,label="Bars 2",color="r")
plt.xlabel("x")
plt.ylabel("y")

plt.title("Satarting matplotlib\nCheck it out")
plt.legend()
plt.show()

# %%
population=[0,20,40,23,43,24,25,26,29,100]
bins=range(0,100,10)
plt.hist(population,bins,label="Population histogram")
plt.show()

# %%
x=[2,4,6,8,10]
y=[5,6,7,8,4]
plt.title("Satarting matplotlib\nCheck it out")


plt.scatter(x,y,label="Scatteer Plot",color="r",marker="V",s=50)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ccce704f355e> in <module>()
#       4
#       5
# ----> 6 plt.scatter(x,y,label="Scatteer Plot",color="r",marker="V",s=50)
#       7 plt.legend()
#       8 plt.show()
#
# C:\Users\RSB\Anaconda2\envs\dato-env\lib\site-packages\matplotlib\pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3249                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3250                          linewidths=linewidths, verts=verts,
# -> 3251                          edgecolors=edgecolors, data=data, **kwargs)
#    3252     finally:
#    3253         ax.hold(washold)
#
# C:\Users\RSB\Anaconda2\envs\dato-env\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
# ...

# %%
days=[1,2,3,4,5]
sleeping=[7,8,6,11,7]
eating=[3,3,4,3,2]
working=[7,8,7,2,6]
playing=[7,5,7,8,9]
plt.title("Satarting matplotlib\nCheck it out")
plt.stackplot(days,sleeping,eating,working,playing,color=["r","c","m","b"])

#for legends
plt.plot([],[],label="Sleeping",color="r")
plt.plot([],[],label="Eating",color="c")
plt.plot([],[],label="Working",color="m")
plt.plot([],[],label="Playing",color="k")


plt.legend()
plt.show()

# %%
sleeping=[7,8,6,11,7]
eating=[3,3,4,3,2]
working=[7,8,7,2,6]
playing=[7,5,7,8,9]
slices = [np.array(sleeping).sum(),
          np.array(eating).sum(),
          np.array(working).sum(),
          np.array(playing).sum()]

activities = ['sleeping','eating','working','playing']
color = ['c','m','r','b']
plt.pie(slices,
        labels=activities,
        colors=color,
        startangle=90,
        shadow=True,
        explode=(0,0.1,0,0),autopct=("%1.1f%%")   )
plt.legend()
plt.show()

# %%
# Out:
# 39
